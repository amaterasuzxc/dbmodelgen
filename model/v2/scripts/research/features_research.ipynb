# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load("ru_core_news_lg")

# %%
doc = nlp("Нужно хранить следующую информацию о клиенте: имя, адрес, телефон.")

options = {"bg": "white", "distance": 130,
           "color": "black", "font": "Source Sans Pro"}
displacy.render(doc, style="dep", options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ru" id="03035ee848e04f7fbe34427186e1b350-0" class="displacy" width="1220" height="267.0" direction="ltr" style="max-width: none; height: 267.0px; color: black; background: white; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="177.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Нужно</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="177.0">
#     <tspan class="displacy-word" fill="currentColor" x="180">хранить</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="180">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="177.0">
# ...

# %%
doc = nlp("Таблица \"клиенты\" (имя, адрес, телефон)")

options = {"bg": "white", "distance": 130,
           "color": "black", "font": "Source Sans Pro"}
displacy.render(doc, style="dep", options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ru" id="61b6da57092d40beabd64323cdd7065a-0" class="displacy" width="700" height="267.0" direction="ltr" style="max-width: none; height: 267.0px; color: black; background: white; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="177.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Таблица &quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="177.0">
#     <tspan class="displacy-word" fill="currentColor" x="180">клиенты&quot; (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="180">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="177.0">
# ...
