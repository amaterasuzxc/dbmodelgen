# %%
import pandas as pd
import numpy as np
from pyxtension.streams import stream

# %%
df = pd.read_excel('../formatted_dataset.xlsx')

# %%
df = df[['Text','Entity']]
df = df.replace(r'\n', ' ', regex=True)
for i in range(0, df.Entity.size):
    e = df.Entity[i]
    df.Entity[i] = stream(e.split(',')).map(lambda x: x.strip()).toList()
df.head()
# Out:
#                                                 Text  \
# 0  Предметная область Предприятие по реализации т...
# 1  Предметная область Ремонтная мастерская занима...
# 2  Предметная область Фирма по прокату автомобиле...
# 3  Предметная область Работа гостиницы. Бизнес-пр...
# 4  Предметная область Ремонт автомобиля. Бизнес-п...
#
#                                               Entity
# 0  [товар, клиент, поставщик, сотрудник, заказ, д...
# 1  [изделие, клиент, сотрудник, деталь, заказ_кли...
# 2  [автомобиль, клиент, страховая_компания, сотру...
# 3           [номер, сотрудник, гость, услуга, бронь]
# 4  [автомобиль, клиент, бригада, деталь, договор,...

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_ru')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\amatemeow\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]     C:\Users\amatemeow\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_ru.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\amatemeow\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\amatemeow\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\amatemeow\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pymorphy3
morph = pymorphy3.MorphAnalyzer()

# %%
ex_text = df.Text[0]
tokens = nltk.word_tokenize(ex_text, language='russian')
tokens = list(map(lambda _:morph.parse(_)[0].normal_form, tokens))
print(tokens)
tagged = nltk.pos_tag(tokens, lang='rus')
chunks = nltk.ne_chunk(tagged)
chunks
# Out:
# ['предметный', 'область', 'предприятие', 'по', 'реализация', 'товар', 'по', 'заказ', '.', 'предприятие', 'располагать', 'склад', ',', 'на', 'который', 'храниться', 'товар', '.', 'для', 'получение', 'товар', 'клиент', 'оформлять', 'заказ', '.', 'для', 'пополнение', 'товар', 'на', 'склад', 'предприятие', 'заключать', 'договор', 'с', 'поставщик', '.', 'бизнес-правило', '1', '.', 'организация', 'формировать', 'заказ', 'из', 'товар', ',', 'иметься', 'на', 'склад', '.', '2', '.', 'клиент', 'мочь', 'оформить', 'заказ', 'на', 'несколько', 'товар', '.', '3', '.', 'формирование', 'заказ', 'заниматься', 'один', 'сотрудник', '.', 'минимальный', 'набор', 'сущность', ':', 'товар', ',', 'клиент', ',', 'поставщик', ',', 'сотрудник', '.', 'минимальный', 'набор', 'атрибут', ':', 'наименование', 'товар', ',', 'назначение', 'товар', ',', 'стоимость', 'товар', ';', 'фамилия', 'клиент', ',', 'контактный', 'дать', 'клиент', ',', 'адрес', 'клиент', ';', 'название', 'фирма', 'поставщик', ',', 'фамилия', 'рук
# ...
